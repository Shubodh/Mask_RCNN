# %%
from pycocotools.coco import COCO
from pycocotools.cocoeval import COCOeval
from pycocotools import mask as maskUtils

import json

# %%
coco = COCO("/scratch/shubodh/random/instances_minival2014.json")
# coco_balloon = COCO("/scratch/shubodh/random/via_region_data.json")
coco_rrc = COCO("/scratch/shubodh/neon_test_dataset_maskrcnn/train/annotations.json")
# coco.imgs.keys()
# Out:
# loading annotations into memory...
# Done (t=0.98s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-33-5706efc1df43> in <module>
#       1 coco = COCO("/scratch/shubodh/random/instances_minival2014.json")
#       2 # coco_balloon = COCO("/scratch/shubodh/random/via_region_data.json")
# ----> 3 coco_rrc = COCO("/scratch/shubodh/neon_test_dataset_maskrcnn/train/annotations.json")
#       4 # coco.imgs.keys()
#
# ~/MaskRCNN_training/Mask_RCNN/env_maskrcnn_train/lib/python3.6/site-packages/pycocotools-2.0-py3.6-linux-x86_64.egg/pycocotools/coco.py in __init__(self, annotation_file)
#      86             print('Done (t={:0.2f}s)'.format(time.time()- tic))
#      87             self.dataset = dataset
# ---> 88             self.createIndex()
#      89
# ...

# %%
annotations = json.load(open("/scratch/shubodh/random/via_region_data.json"))
annotations = list(annotations.values())
annotations
# Out:
# [{'fileref': '',
#   'size': 1115004,
#   'filename': '34020010494_e5cb88e1c4_k.jpg',
#   'base64_img_data': '',
#   'file_attributes': {},
#   'regions': {'0': {'shape_attributes': {'name': 'polygon',
#      'all_points_x': [1020,
#       1000,
#       994,
#       1003,
#       1023,
#       1050,
#       1089,
#       1134,
#       1190,
#       1265,
#       1321,
#       1361,
#       1403,
#       1428,
#       1442,
#       1445,
#       1441,
#       1427,
#       1400,
#       1361,
#       1316,
#       1269,
#       1228,
#       1198,
#       1207,
#       1210,
#       1190,
#       1177,
#       1172,
#       1174,
#       1170,
#       1153,
#       1127,
#       1104,
#       1061,
#       1032,
#       1020],
#      'all_points_y': [963,
#       899,
#       841,
#       787,
#       738,
#       700,
#       663,
#       638,
#       621,
#       619,
#       643,
#       672,
#       720,
#       765,
#       800,
#       860,
#       896,
#       942,
# ...

# %%
dataset_dir = "/scratch/shubodh/neon_test_dataset_maskrcnn"
subset = "train"

# rrc_json = COCO("{}/{}/annotations.json".format(dataset_dir, subset))
annotations = json.load(open("/scratch/shubodh/neon_test_dataset_maskrcnn/train/annotations.json"))
annotations
# Out:
# {'info': {'description': None,
#   'url': None,
#   'version': None,
#   'year': 2019,
#   'contributor': None,
#   'date_created': '2019-02-22 15:17:34.616323'},
#  'licenses': [{'url': None, 'id': 0, 'name': None}],
#  'images': [{'license': 0,
#    'url': None,
#    'file_name': 'JPEGImages/frame0085.jpg',
#    'height': 480,
#    'width': 640,
#    'date_captured': None,
#    'id': 0},
#   {'license': 0,
#    'url': None,
#    'file_name': 'JPEGImages/frame0473.jpg',
#    'height': 480,
#    'width': 640,
#    'date_captured': None,
#    'id': 1},
#   {'license': 0,
#    'url': None,
#    'file_name': 'JPEGImages/frame1180.jpg',
#    'height': 480,
#    'width': 640,
#    'date_captured': None,
#    'id': 2},
#   {'license': 0,
#    'url': None,
#    'file_name': 'JPEGImages/frame0744.jpg',
#    'height': 480,
#    'width': 640,
#    'date_captured': None,
#    'id': 3},
#   {'license': 0,
#    'url': None,
#    'file_name': 'JPEGImages/frame0234.jpg',
#    'height': 480,
# ...
